# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/metodos_numericosU6/blob/main/Comparaci%C3%B3n_con_soluci%C3%B3n_exacta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 2 - Comparación con solución exacta

# %%
import numpy as np    # Biblioteca numérica

def f(x,y):    # Define EDO
    return x + y    # Define dy/dx

def exacta(x):    # Define solución analítica
    return 2*np.exp(x) - x - 1    # Fórmula exacta

x = 0    # Valor inicial

y = 1    # Condición inicial

h = 0.1    # Tamaño del paso

for i in range(10):    # Ejecuta iteraciones

    y = y + h*f(x,y)    # Euler

    x = x + h    # Incrementa x

    real = exacta(x)    # Calcula solución exacta

    error = abs(real-y)    # Calcula error absoluto

    print("x =",x,
        "Euler =",y,
        "Exacta =",real,
        "Error =",error)
# Out:
# x = 0.1 Euler = 1.1 Exacta = 1.1103418361512953 Error = 0.010341836151295247
# x = 0.2 Euler = 1.2200000000000002 Exacta = 1.2428055163203395 Error = 0.022805516320339336
# x = 0.30000000000000004 Euler = 1.362 Exacta = 1.3997176151520065 Error = 0.037717615152006445
# x = 0.4 Euler = 1.5282 Exacta = 1.5836493952825408 Error = 0.05544939528254078
# x = 0.5 Euler = 1.72102 Exacta = 1.7974425414002564 Error = 0.0764225414002564
# x = 0.6 Euler = 1.943122 Exacta = 2.0442376007810177 Error = 0.10111560078101767
# x = 0.7 Euler = 2.1974342 Exacta = 2.327505414940953 Error = 0.13007121494095308
# x = 0.7999999999999999 Euler = 2.48717762 Exacta = 2.651081856984935 Error = 0.16390423698493484
# x = 0.8999999999999999 Euler = 2.8158953820000003 Exacta = 3.0192062223138993 Error = 0.203310840313899
# x = 0.9999999999999999 Euler = 3.1874849202 Exacta = 3.43656365691809 Error = 0.24907873671809
