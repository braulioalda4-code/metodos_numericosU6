# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/metodos_numericosU6/blob/main/Aplicaci%C3%B3n_IA_din%C3%A1mica_de_pesos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 4 - Aplicación IA: dinámica de pesos

# %%
11

import numpy as np    # Importa NumPy

def f(t,w):    # Define ecuación diferencial
    return -0.5*w    # Modelo de decaimiento

t = 0    # Tiempo inicial

w = 10    # Peso inicial

h = 0.1    # Paso temporal

for i in range(20):    # Ejecuta RK4

    k1 = f(t,w)    # Primera pendiente

    k2 = f(t+h/2, w+h*k1/2)    # Segunda pendiente

    k3 = f(t+h/2, w+h*k2/2)    # Tercera pendiente

    k4 = f(t+h, w+h*k3)    # Cuarta pendiente

    w = w + (h/6)*(k1 + 2*k2 + 2*k3 + k4)    # Actualización

    t = t + h    # Incrementa tiempo

    print("t =",t,"w =",w)    # Muestra evolución
# Out:
# t = 0.1 w = 9.512294270833333
# t = 0.2 w = 9.048374229492866
# t = 0.30000000000000004 w = 8.607079834356098
# t = 0.4 w = 8.187307619695062
# t = 0.5 w = 7.788007936437544
# t = 0.6 w = 7.408182327497938
# t = 0.7 w = 7.046881031114738
# t = 0.7999999999999999 w = 6.7032006059516815
# t = 0.8999999999999999 w = 6.376281672024071
# t = 0.9999999999999999 w = 6.065306761801415
# t = 1.0999999999999999 w = 5.769498276113028
# t = 1.2 w = 5.488116539745275
# t = 1.3 w = 5.220457951868464
# t = 1.4000000000000001 w = 4.965853226668471
# t = 1.5000000000000002 w = 4.723665719783772
# t = 1.6000000000000003 w = 4.493289836363099
# t = 1.7000000000000004 w = 4.274149516763035
# t = 1.8000000000000005 w = 4.065696796099007
# t = 1.9000000000000006 w = 3.8674104340478026
# t = 2.0000000000000004 w = 3.678794611475397
